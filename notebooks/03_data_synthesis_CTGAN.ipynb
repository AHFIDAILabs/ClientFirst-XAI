# %%
# Install library

# !pip install sdv > /dev/null 2>&1

# %%
from google.colab import drive
import os
import pandas as pd
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata
from sklearn.utils import shuffle

# Mount Google Drive
drive.mount('/content/drive')

# File paths
dir = '/content/drive/MyDrive/HIV-Exp-Project/Data'
file_path = os.path.join(dir, "clients_data.csv")

# Load and clean
df = pd.read_csv(file_path)

# ✅ Filter for only valid states and convert to string (not category dtype)
valid_states = ["Bauchi", "Jigawa", "Kano"]
df = df[df["State"].isin(valid_states)].copy()
df["State"] = df["State"].astype(str)

# Drop rows with missing satisfaction
df.dropna(subset=["Visit_Satisfaction"], inplace=True)

# Remove EnumID if it exists
df_model = df.drop(columns=["EnumID"], errors="ignore")

# Define sample sizes for synthetic generation
minority_targets = {
    "Satisfied": 270,
    "Neutral": 370,
    "Very dissatisfied": 370
}

synthetic_samples = []
synthetic_id_counter = 1

# Loop through each minority class and generate synthetic data
for target_value, num_samples in minority_targets.items():
    print(f"\nGenerating samples for: {target_value}")

    subset = df_model[df_model["Visit_Satisfaction"] == target_value].copy()

    # ✅ Ensure state values are valid and string-typed
    subset = subset[subset["State"].isin(valid_states)].copy()
    subset["State"] = subset["State"].astype(str)

    # Build metadata
    metadata = SingleTableMetadata()
    metadata.detect_from_dataframe(subset)

    # Explicitly mark 'State' as categorical if it's not already
    if metadata.columns["State"]["sdtype"] != "categorical":
        metadata.update_column(column_name="State", sdtype="categorical")

    # Train and sample
    model = CTGANSynthesizer(metadata)
    model.fit(subset)

    synth = model.sample(num_rows=num_samples)

    # Add synthetic IDs
    synth["EnumID"] = [
        f"SYNTH-{target_value[:3].upper()}-{i+1}"
        for i in range(synthetic_id_counter, synthetic_id_counter + num_samples)
    ]
    synthetic_id_counter += num_samples

    synthetic_samples.append(synth)
    print(f"✅ Generated {num_samples} samples for: {target_value}")

# Combine synthetic and original data
synthetic_df = pd.concat(synthetic_samples, ignore_index=True)
synthetic_df["Source"] = "Synthetic"
df["Source"] = "Original"

# Merge and shuffle
balanced_df = pd.concat([df, synthetic_df], ignore_index=True)
balanced_df = shuffle(balanced_df, random_state=42)

# Save final dataset
output_path = os.path.join(dir, "balanced.csv")
balanced_df.to_csv(output_path, index=False)
print(f"\n✅ Saved balanced dataset to: {output_path}")
# Out:
# Mounted at /content/drive
#
# Generating samples for: Satisfied
# /usr/local/lib/python3.11/dist-packages/sdv/single_table/base.py:163: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /usr/local/lib/python3.11/dist-packages/sdv/single_table/base.py:129: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# ✅ Generated 270 samples for: Satisfied
#
# Generating samples for: Neutral
# /usr/local/lib/python3.11/dist-packages/sdv/single_table/base.py:163: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /usr/local/lib/python3.11/dist-packages/sdv/single_table/base.py:129: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# ✅ Generated 370 samples for: Neutral
#
# Generating samples for: Very dissatisfied
# /usr/local/lib/python3.11/dist-packages/sdv/single_table/base.py:163: FutureWarning: The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#   warnings.warn(DEPRECATION_MSG, FutureWarning)
# /usr/local/lib/python3.11/dist-packages/sdv/single_table/base.py:129: UserWarning: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
#   warnings.warn(
# ✅ Generated 370 samples for: Very dissatisfied
#
# ✅ Saved balanced dataset to: /content/drive/MyDrive/HIV-Exp-Project/Data/balanced.csv

# %%
from sdv.evaluation.single_table import run_diagnostic

diagnostic = run_diagnostic(
        df,
    synthetic_df,
    metadata
)
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 33/33 [00:00<00:00, 992.46it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 77.45it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%

# %%
from sdv.evaluation.single_table import evaluate_quality
from sdv.metadata import SingleTableMetadata

# Create new metadata that matches the columns in both dataframes
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data=df.drop(columns=["EnumID", "Source"], errors="ignore"))


quality_report = evaluate_quality(
    df.drop(columns=["EnumID", "Source"], errors="ignore"),
    synthetic_df.drop(columns=["EnumID", "Source"], errors="ignore"),
    metadata
)
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 33/33 [00:00<00:00, 1113.73it/s]|
# Column Shapes Score: 84.67%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 528/528 [00:02<00:00, 180.60it/s]|
# Column Pair Trends Score: 71.9%
#
# Overall Score (Average): 78.28%

# %%
quality_report.get_details('Column Shapes')
# Out:
#                       Column        Metric     Score
# 0                        Age  TVComplement  0.757779
# 1                     Gender  TVComplement  0.843159
# 2             Marital Status  TVComplement  0.794699
# 3             Family Setting  TVComplement  0.850146
# 4            Num of Children  TVComplement  0.763225
# 5         Educational Status  TVComplement  0.822427
# 6          Employment Status  TVComplement  0.827668
# 7             Monthly Income  TVComplement  0.887040
# 8          Treatment Regimen  TVComplement  0.884731
# 9         HIV_Duration_Years  TVComplement  0.850402
# 10       Care_Duration_Years  TVComplement  0.906945
# 11   Facility_Care_Dur_Years  TVComplement  0.869043
# 12             HIV_Diag_Type  TVComplement  0.848509
# 13             Greet_Comfort  TVComplement  0.814493
# 14       Discuss_VisitReason  TVComplement  0.946619
# 15        Encourage_Thoughts  TVComplement  0.876092
# 16            Listen_Careful  TVComplement  0.933014
# 17            Understood_You  TVComplement  0.921439
# 18            Exam_Explained  TVComplement  0.904900
# 19        LabTests_Explained  TVComplement  0.804275
# 20      Discuss_TreatOptions  TVComplement  0.815930
# 21            Info_AsDesired  TVComplement  0.950380
# 22  Plan_Acceptability_Check  TVComplement  0.935359
# 23     Meds_Explained_SideFX  TVComplement  0.923732
# 24       Encourage_Questions  TVComplement  0.968057
# 25        Respond_Q_Concerns  TVComplement  0.787492
# 26   Showed_Personal_Concern  TVComplement  0.864068
# 27     Involved_In_Decisions  TVComplement  0.855534
# 28         Discuss_NextSteps  TVComplement  0.838194
# 29     Checked_Understanding  TVComplement  0.901948
# 30       Time_Spent_Adequate  TVComplement  0.909338
# 31        Visit_Satisfaction  TVComplement  0.236253

# %%
from sdv.evaluation.single_table import get_column_plot

fig = get_column_plot(
    df,
    synthetic_df,
    column_name='Visit_Satisfaction',
    metadata=metadata
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a15daa7d-17ba-4636-b924-ea6907713510" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a15daa7d-17ba-4636-b924-ea6907713510")) {                    Plotly.newPlot(                        "a15daa7d-17ba-4636-b924-ea6907713510",                        [{"alignmentgroup":"True","bingroup":"x","histnorm":"probability density","hovertemplate":"\u003cb\u003eReal\u003c\u002fb\u003e\u003cbr\u003eFrequency: %{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Real","marker":{"color":"#000036","pattern":{"shape":""}},"name":"Real","offsetgroup":"Real","orientation":"v","showlegend":true,"x":["Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Very satisfied","Satisfied","Satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Neutral","Very satisfied","Satisfied","Very satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very dissatisfied","Very satisfied","Satisfied","Very dissatisfied","Very satisfied","Very dissatisfied","Satisfied","Very satisfied","Satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Very satisfied","Satisfied","Very satisfied","Very satisfied", ...

# %%
balanced_df.head()
# Out:
#              EnumID   State                 Age  Gender Marital Status  \
# 1117  SYNTH-NEU-628  Bauchi               25-34  Female         Single
# 643   SYNTH-SAT-154    Kano  55 years and above  Female         Single
# 422           BC023  Bauchi               35–44  Female        Married
# 413            KN27    Kano  55 years and above  Female       Divorced
# 451           BC023  Bauchi               35–44    Male        Married
#
#      Family Setting Num of Children   Educational Status  \
# 1117       Monogamy             3-4    Primary education
# 643        Monogamy  Greater than 4  No formal education
# 422        Monogamy             1-2  Secondary education
# 413        Monogamy  Greater than 4  No formal education
# 451        Monogamy             3-4  Secondary education
#
#            Employment Status         Monthly Income  ...  \
# 1117           Self-employed  101,000–200,000 Naira  ...
# 643            Self-employed   51,000–100,000 Naira  ...
# 422               Unemployed      Prefer not to say  ...
# 413               Unemployed      Prefer not to say  ...
# 451   Other (please specify)   51,000–100,000 Naira  ...
#
#      Meds_Explained_SideFX        Encourage_Questions Respond_Q_Concerns  \
# 1117                 Agree                      Agree              Agree
# 643         Strongly Agree                      Agree              Agree
# 422                  Agree                      Agree           Disagree
# 413         Strongly Agree                   Disagree     Strongly Agree
# 451                  Agree  Neither Agree or Disagree              Agree
#
#         Showed_Personal_Concern Involved_In_Decisions  \
# 1117  Neither Agree or Disagree                 Agree
# 643                    Disagree        Strongly Agree
# 422                    Disagree        Strongly Agree
# 413              Strongly Agree        Strongly Agree
# 451                       Agree                 Agree
#
#               Discuss_NextSteps Checked_Understanding Time_Spent_Adequate  \
# 1117  Neither Agree or Disagree        Strongly Agree               Agree
# 643                       Agree                 Agree               Agree
# 422              Strongly Agree        Strongly Agree               Agree
# 413              Strongly Agree        Strongly Agree      Strongly Agree
# 451              Strongly Agree                 Agree               Agree
#
#      Visit_Satisfaction     Source
# 1117            Neutral  Synthetic
# 643           Satisfied  Synthetic
# 422      Very satisfied   Original
# 413      Very satisfied   Original
# 451      Very satisfied   Original
#
# [5 rows x 35 columns]

# %%
balanced_df['Visit_Satisfaction'].value_counts()
# Out:
# Visit_Satisfaction
# Neutral              376
# Satisfied            376
# Very satisfied       375
# Very dissatisfied    374
# Name: count, dtype: int64
